# %% [markdown]
# ### Load Data

# %%
# Import Libraries|
import pandas as pd
import numpy as np
import seaborn as sns
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
with open('../datasets/traffic-signs/train.p', mode='rb') as training_data:
    train = pickle.load(training_data)
    
with open('../datasets/traffic-signs/valid.p', mode='rb') as validation_data:
    valid = pickle.load(validation_data)
    
with open('../datasets/traffic-signs/test.p', mode='rb') as testing_data:
    test = pickle.load(testing_data)

# %%
train.keys()
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
valid.keys()
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
test.keys()
# Out:
# dict_keys(['sizes', 'coords', 'features', 'labels'])

# %%
X_train, y_train = train['features'], train['labels']
X_validation, y_validation = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %%
print(X_train.shape)
print(y_train.shape)
print(X_validation.shape)
print(y_validation.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (34799, 32, 32, 3)
# (34799,)
# (4410, 32, 32, 3)
# (4410,)
# (12630, 32, 32, 3)
# (12630,)

# %% [markdown]
# ### Explore data

# %%
i = 3000

plt.imshow(X_train[i])
y_train[i]
# Out:
# 1

# %%
i = 3000

plt.imshow(X_validation[i])
y_validation[i]
# Out:
# 7

# %%
# Create grid for images

W_grid = 15
L_grid = 15

fig, axes = plt.subplots(L_grid, W_grid, figsize = (25,25))
#Flatten
axes = axes.ravel()

n_training = len(X_train)

for i in np.arange(0, L_grid * W_grid):
    index = np.random.randint(0, n_training)
    axes[i].imshow(X_train[index])
    axes[i].axis('off')
    axes[i].set_title(y_train[index])
    
plt.subplots_adjust(hspace = 0.4)

# %% [markdown]
# ### Data Prep

# %%
# Shuffle images

from sklearn.utils import shuffle
X_train, y_train = shuffle(X_train, y_train)

# %%
#change datasets to gray scale

X_train_gray = np.sum(X_train/3, axis = 3, keepdims = True)
X_val_gray = np.sum(X_validation/3, axis = 3, keepdims = True)
X_test_gray = np.sum(X_test/3, axis = 3, keepdims = True)

# %%
print(X_train.shape)
print(X_train_gray.shape)

print(X_validation.shape)
print(X_val_gray.shape)

print(X_test.shape)
print(X_test_gray.shape)
# Out:
# (34799, 32, 32, 3)
# (34799, 32, 32, 1)
# (4410, 32, 32, 3)
# (4410, 32, 32, 1)
# (12630, 32, 32, 3)
# (12630, 32, 32, 1)

# %%
# Normalize
X_train_gray_norm = (X_train_gray - 128)/128
X_val_gray_norm = (X_val_gray - 128)/128
X_test_gray_norm = (X_test_gray - 128)/128

# %%
i = 1000

plt.imshow(X_train_gray_norm[i].squeeze(), cmap='gray')
y_train[i]
plt.figure()
plt.imshow(X_train_gray[i].squeeze(), cmap='gray')
plt.figure()
plt.imshow(X_train[i])

# %% [markdown]
# ### Model

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
# Out:
# Using TensorFlow backend.

# %%
input_dim = X_train_gray_norm.shape[1:]

# %%
input_dim
# Out:
# (32, 32, 1)

# %%
model = Sequential()

model.add(Conv2D(filters=6, kernel_size=(5,5), activation='relu', input_shape= input_dim))
model.add(AveragePooling2D())

model.add(Conv2D(filters=16, kernel_size=(5,5), activation='relu', input_shape= input_dim))
model.add(AveragePooling2D())

model.add(Flatten())

model.add(Dense(units = 120, activation = 'relu'))
model.add(Dense(units = 84, activation = 'relu'))

model.add(Dense(units = 43, activation = 'softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 400)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               48120
# _________________________________________________________________
# dense_2 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_3 (Dense)              (None, 43)                3655
# =================================================================
# Total params: 64,511
# Trainable params: 64,511
# Non-trainable params: 0
# _________________________________________________________________

# %%
print(y_train.shape)
print(y_test.shape)
print(y_validation.shape)
# Out:
# (34799,)
# (12630,)
# (4410,)

# %%
import keras
# Number of Categories
number_cat = 43
y_train = keras.utils.to_categorical(y_train, number_cat)
y_test = keras.utils.to_categorical(y_test, number_cat)
y_validation = keras.utils.to_categorical(y_validation, number_cat)

# %%
print(y_train.shape)
print(y_test.shape)
print(y_validation.shape)
# Out:
# (34799, 43)
# (12630, 43)
# (4410, 43)

# %%
model.compile(loss = 'categorical_crossentropy',
            optimizer = Adam(lr = 0.001),
            metrics = ['accuracy'])

# %%
model_hist = model.fit(X_train_gray_norm,
                   y_train,
                   batch_size=500,
                   nb_epoch=30,
                   #shuffle=True,
                   verbose = 1,
                   validation_data = (X_val_gray_norm, y_validation))
# Out:
# Train on 34799 samples, validate on 4410 samples
# Epoch 1/30
#  4500/34799 [==>...........................] - ETA: 1s - loss: 0.5178 - acc: 0.8640
# C:\Users\Sage\Anaconda3\envs\cv_tf_gpu\lib\site-packages\ipykernel_launcher.py:7: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   import sys
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.4908 - acc: 0.8697 - val_loss: 0.7139 - val_acc: 0.7921
# Epoch 2/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.4122 - acc: 0.8913 - val_loss: 0.6596 - val_acc: 0.8027
# Epoch 3/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.3541 - acc: 0.9080 - val_loss: 0.6620 - val_acc: 0.8141
# Epoch 4/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.3081 - acc: 0.9197 - val_loss: 0.6765 - val_acc: 0.8156
# Epoch 5/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.2777 - acc: 0.9284 - val_loss: 0.6164 - val_acc: 0.8227
# Epoch 6/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.2448 - acc: 0.9374 - val_loss: 0.6400 - val_acc: 0.8274
# Epoch 7/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.2264 - acc: 0.9424 - val_loss: 0.6609 - val_acc: 0.8240
# Epoch 8/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.2093 - acc: 0.9457 - val_loss: 0.6799 - val_acc: 0.8254
# Epoch 9/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.1900 - acc: 0.9513 - val_loss: 0.6091 - val_acc: 0.8399
# Epoch 10/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.1682 - acc: 0.9573 - val_loss: 0.6126 - val_acc: 0.8490
# Epoch 11/30
# 34799/34799 [==============================] - 1s 32us/step - loss: 0.1594 - acc: 0.9589 - val_loss: 0.6178 - val_acc: 0.8456
# Epoch 12/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.1403 - acc: 0.9646 - val_loss: 0.6065 - val_acc: 0.8524
# Epoch 13/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.1325 - acc: 0.9672 - val_loss: 0.6597 - val_acc: 0.8451
# Epoch 14/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.1224 - acc: 0.9692 - val_loss: 0.6738 - val_acc: 0.8515
# Epoch 15/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.1179 - acc: 0.9699 - val_loss: 0.6360 - val_acc: 0.8574
# Epoch 16/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.1066 - acc: 0.9726 - val_loss: 0.6710 - val_acc: 0.8553
# Epoch 17/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.1015 - acc: 0.9739 - val_loss: 0.6604 - val_acc: 0.8567
# Epoch 18/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0928 - acc: 0.9769 - val_loss: 0.7389 - val_acc: 0.8365
# Epoch 19/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0897 - acc: 0.9763 - val_loss: 0.7005 - val_acc: 0.8469
# Epoch 20/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.0812 - acc: 0.9796 - val_loss: 0.7070 - val_acc: 0.8524
# Epoch 21/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0752 - acc: 0.9813 - val_loss: 0.7336 - val_acc: 0.8537
# Epoch 22/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0776 - acc: 0.9800 - val_loss: 0.7538 - val_acc: 0.8522
# Epoch 23/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.0698 - acc: 0.9828 - val_loss: 0.7014 - val_acc: 0.8488
# Epoch 24/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0625 - acc: 0.9851 - val_loss: 0.7265 - val_acc: 0.8576
# Epoch 25/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0598 - acc: 0.9860 - val_loss: 0.7480 - val_acc: 0.8580
# Epoch 26/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.0616 - acc: 0.9847 - val_loss: 0.8054 - val_acc: 0.8454
# Epoch 27/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0545 - acc: 0.9872 - val_loss: 0.8276 - val_acc: 0.8517
# Epoch 28/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.0542 - acc: 0.9864 - val_loss: 0.7654 - val_acc: 0.8567
# Epoch 29/30
# 34799/34799 [==============================] - 1s 30us/step - loss: 0.0526 - acc: 0.9871 - val_loss: 0.7629 - val_acc: 0.8599
# Epoch 30/30
# 34799/34799 [==============================] - 1s 31us/step - loss: 0.0452 - acc: 0.9892 - val_loss: 0.7887 - val_acc: 0.8544

# %%
plt.plot(model_hist.history['loss'])
plt.plot(model_hist.history['acc'])
plt.xlabel('Epoch')
plt.ylabel('acc')
plt.title('')
plt.legend(['loss', 'acc'])

# %%
evaluation = model.evaluate(X_test_gray_norm, y_test)
# Out:
# 12630/12630 [==============================] - 1s 65us/step

# %%
print('Test Accuracy: {}'.format(evaluation[1]))
